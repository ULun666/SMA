# %% [markdown]
# ### 1.

# %%
import pandas as pd

# %%
df = pd.read_csv("data/fianlexam_edges.csv")
df
# Out:
#    source target
# 0       G      L
# 1       O      B
# 2       O      C
# 3       S      O
# 4       X      D
# 5       A      Q
# 6       D      E
# 7       C      M
# 8       Y      N
# 9       B      Y
# 10      O      Q
# 11      Q      F
# 12      O      K
# 13      V      Q
# 14      T      H
# 15      L      G
# 16      P      D
# 17      U      S
# 18      Q      O
# 19      G      U
# 20      A      Z
# 21      I      D
# 22      X      Z
# 23      A      E
# 24      Q      V
# 25      N      F
# 26      Y      Q
# 27      U      L
# 28      Y      D
# 29      B      Z
# 30      B      S
# 31      W      N
# 32      H      S
# 33      D      B
# 34      M      F
# 35      L      W
# 36      H      X
# 37      Y      J
# 38      P      S
# 39      H      T
# 40      U      M
# 41      R      T
# 42      U      F
# 43      E      P
# 44      V      T
# 45      T      F
# 46      N      D
# 47      C      Z
# 48      W      C
# 49      Q      H
# 50      J      Z
# ...
