# %% [markdown]
# # 第十一週：Text Embeddings
#
# 本週課程為「Text Embeddings」，主要會使用到gensim套件來實現自行訓練word2vec模型以及使用預訓練word2vec模型，以及透過sentence-transformers套件和API取得embeddings。

# %% [markdown]
# ### 大綱：
# 1.   DEMO
# *   Word2Vec
#   *   自己訓練w2v模型
#   *   使用別人訓練好的w2v模型
# *   Transformers Embeddings
#   *   小模型（BERT）：
#       *   不同語言的BERT：uncased / chinese / multilingual
#   *   大模型（LLM）：
#       *   API based
#       *   Open Source LLM
#
# 2.   資料集實作任務
# *    使用embedding 做 NLP 任務
#   *   找相似文件（文章）
#   *   文件分類任務

# %% [markdown]
# ### 套件安裝

# %% [markdown]
# 連接雲端資料夾

# %%
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('雲端資料夾路徑') #切換該目錄
os.listdir() #確認目錄內容

# %%
# !pip install jieba
# !pip install "gensim==4.3.3" "spacy==3.7.2" "thinc==8.2.2"

# %% [markdown]
# 如果安裝套件時遇到跟 numpy 相關錯誤的話，可以嘗試執行以下程式碼

# %%
# 先清除舊的 numpy
# !pip uninstall -y numpy

# 安裝對應版本
# !pip install numpy==1.26.4 gensim==4.3.3 spacy==3.7.2 thinc==8.2.2

# 強制重啟 Runtime
import os
os.kill(os.getpid(), 9)

# %%
import pandas as pd
import jieba
import jieba.analyse
import re
import numpy as np
from collections import defaultdict
import multiprocessing

from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec, KeyedVectors

from gensim.models import Word2Vec

import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import torch

from matplotlib.font_manager import fontManager
import plotly.express as px

sns.set_style("darkgrid")

# %% [markdown]
# ### 資料前處理

# %% [markdown]
# 讀入吃到飽示範資料集

# %%
# 設定繁體中文詞庫
jieba.set_dictionary('./dict/dict.txt.big')
jieba.load_userdict('./dict/user_dict.txt')

# 新增stopwords
with open('./dict/stopwords.txt',encoding="utf-8") as f:
    stopWords = [line.strip() for line in f.readlines()]
# Out:
# Building prefix dict from /content/drive/MyDrive/113_2_SMA/week11/dict/dict.txt.big ...
# DEBUG:jieba:Building prefix dict from /content/drive/MyDrive/113_2_SMA/week11/dict/dict.txt.big ...
# Dumping model to file cache /tmp/jieba.uab8c42ce1bbcab902d267f29fb9dc9f0.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.uab8c42ce1bbcab902d267f29fb9dc9f0.cache
# Loading model cost 1.592 seconds.
# DEBUG:jieba:Loading model cost 1.592 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.

# %%
# 斷詞函式
def getToken(row):
    seg_list = jieba.lcut(row)
    seg_list = [w for w in seg_list if w not in stopWords and len(w)>1] # 篩選掉停用字與字元數小於1的詞彙

    return seg_list

# %%
# 讀入中文示範資料集
origin_data = pd.read_csv('./raw_data/zh_buffet_20_22.csv')

# %%
# 資料前處理

# 去除一些不需要的欄位
metaData = origin_data.drop(['artPoster', 'artCatagory', 'artComment', 'e_ip', 'insertedDate', 'dataSource'], axis=1)

# 只留下中文字
metaData['sentence'] = metaData['artContent'].str.replace(r'\n\n','。', regex=True)
metaData['sentence'] = metaData['sentence'].str.replace(r'\n','', regex=True)

metaData['sentence'] = metaData['sentence'].str.split("[,，。！!？?]{1,}")
metaData = metaData.explode('sentence').reset_index(drop=True)

metaData['sentence'] = metaData['sentence'].apply(lambda x: re.sub('[^\u4e00-\u9fff]+', '',x))

metaData['word'] = metaData.sentence.apply(getToken)

metaData = metaData[metaData['word'].apply(len) > 0]

metaData.head(10)
# Out:
#     system_id                                             artUrl  \
# 0           1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 1           1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 2           1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 3           1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 4           1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 5           1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 7           2  https://www.ptt.cc/bbs/Food/M.1577983692.A.794...
# 8           2  https://www.ptt.cc/bbs/Food/M.1577983692.A.794...
# 9           2  https://www.ptt.cc/bbs/Food/M.1577983692.A.794...
# 10          2  https://www.ptt.cc/bbs/Food/M.1577983692.A.794...
#
#                artTitle              artDate  \
# 0    [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 1    [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 2    [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 3    [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 4    [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 5    [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 7   [抱怨]ATT4FUN乾杯點沙朗多注意  2020-01-02 16:42:10
# 8   [抱怨]ATT4FUN乾杯點沙朗多注意  2020-01-02 16:42:10
# 9   [抱怨]ATT4FUN乾杯點沙朗多注意  2020-01-02 16:42:10
# 10  [抱怨]ATT4FUN乾杯點沙朗多注意  2020-01-02 16:42:10
#
#                                            artContent  \
# 0   餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 1   餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 2   餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 3   餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 4   餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 5   餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 7   餐廳名稱：乾杯\n\n  地址：ATT4FUN 乾杯\n  電話：02-87860808\n...
# 8   餐廳名稱：乾杯\n\n  地址：ATT4FUN 乾杯\n  電話：02-87860808\n...
# 9   餐廳名稱：乾杯\n\n  地址：ATT4FUN 乾杯\n  電話：02-87860808\n...
# 10  餐廳名稱：乾杯\n\n  地址：ATT4FUN 乾杯\n  電話：02-87860808\n...
#
#                                              sentence  \
# 0                                    餐廳名稱濃咖哩消費時間年月例年月
# 1                                          未提供則文章不予保留
# 2   多訪綜合心得也請標上起迄時間地址台北市開封街段巷號電話營業時間每人平均價位可否刷卡有無包廂推...
# 3   加飯加咖哩醬都免錢一直加飯加醬的話真的可以元吃到飽照片的是雞肉咖哩青菜雞肉用的是雞腿肉大概有...
# 4   其他的口味也吃過肉塊都不少豬肉用的是後腿肉牛肉用的是牛腱肉不會像大部分的平價咖哩飯醬吃起來都...
# 5                老闆不忙的時候會跟客人聊天有時候會招待清湯或紅茶湯的柴魚味超香紅茶也好喝
# 7                                              餐廳名稱乾杯
# 8                        地址乾杯電話消費時間年月號事發經過元旦跟女朋友晚上訂了位
# 9                                           以前都會點上等牛排
# 10                                       吃過很多次覺的品質很穩定
#
#                                                  word
# 0                            [餐廳, 名稱, 咖哩, 消費, 時間, 例年]
# 1                                    [提供, 文章, 不予, 保留]
# 2   [多訪, 綜合, 心得, 標上, 時間, 地址, 台北市, 開封, 街段, 巷號, 電話, ...
# 3   [加飯, 咖哩, 免錢, 加飯, 加醬, 真的, 照片, 雞肉, 咖哩, 青菜, 雞肉, 雞...
# 4   [口味, 過肉塊, 豬肉, 後腿, 牛肉, 牛腱, 大部分, 平價, 咖哩, 飯醬, 味道,...
# 5   [老闆, 不忙, 客人, 聊天, 有時候, 招待, 清湯, 紅茶, 湯的, 魚味, 超香, ...
# 7                                        [餐廳, 名稱, 乾杯]
# 8          [地址, 乾杯, 電話, 消費, 時間, 年月號, 事發, 元旦, 女朋友, 晚上]
# 9                                            [會點, 牛排]
# 10                                       [吃過, 品質, 穩定]

# %% [markdown]
# ### word2vec

# %% [markdown]
# ####（1）如何自己訓練word2vec模型

# %% [markdown]
# 建立訓練資料時將考慮bigram，以下為Phrases函式的使用示範

# %%
docs = ['new york is united states', 'new york is most populated city in the world','i love to stay in new york']

token_ = [doc.split(" ") for doc in docs]
# Phrases 建立bigram,
# 少於min_count的字的字或bigrams會被忽略,
# 大於threshold的bigrams會被加入
bigram = Phrases(token_, min_count=1, threshold=2)
bigram_phraser = Phraser(bigram)

for sent in token_:
    print(sent)  #處理前
    print("=> ",bigram_phraser[sent]) # 處理後，還是原本的句子，只是有抓出的bigram片語會被合併
# Out:
# ['new', 'york', 'is', 'united', 'states']
# =>  ['new_york', 'is', 'united', 'states']
# ['new', 'york', 'is', 'most', 'populated', 'city', 'in', 'the', 'world']
# =>  ['new_york', 'is', 'most', 'populated', 'city', 'in', 'the', 'world']
# ['i', 'love', 'to', 'stay', 'in', 'new', 'york']
# =>  ['i', 'love', 'to', 'stay', 'in', 'new_york']

# %% [markdown]
# 實際應用在資料集上

# %%
sents = metaData['word'].to_list()
bigrams = Phrases(sents,min_count=1, threshold=1000)
bigram_phrasers = Phraser(bigrams)
metaData['word_list_bigrams'] = list(bigram_phrasers[sents])

metaData.head()
# Out:
#    system_id                                             artUrl  \
# 0          1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 1          1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 2          1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 3          1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
# 4          1  https://www.ptt.cc/bbs/Food/M.1577942161.A.AC4...
#
#              artTitle              artDate  \
# 0  [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 1  [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 2  [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 3  [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
# 4  [食記]台北中正濃咖哩平價美味份量大  2020-01-02 05:09:58
#
#                                           artContent  \
# 0  餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 1  餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 2  餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 3  餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
# 4  餐廳名稱：濃咖哩\n   消費時間：2019年1/12月\n          (例：201...
#
#                                             sentence  \
# 0                                   餐廳名稱濃咖哩消費時間年月例年月
# 1                                         未提供則文章不予保留
# 2  多訪綜合心得也請標上起迄時間地址台北市開封街段巷號電話營業時間每人平均價位可否刷卡有無包廂推...
# 3  加飯加咖哩醬都免錢一直加飯加醬的話真的可以元吃到飽照片的是雞肉咖哩青菜雞肉用的是雞腿肉大概有...
# 4  其他的口味也吃過肉塊都不少豬肉用的是後腿肉牛肉用的是牛腱肉不會像大部分的平價咖哩飯醬吃起來都...
#
#                                                 word  \
# 0                           [餐廳, 名稱, 咖哩, 消費, 時間, 例年]
# 1                                   [提供, 文章, 不予, 保留]
# 2  [多訪, 綜合, 心得, 標上, 時間, 地址, 台北市, 開封, 街段, 巷號, 電話, ...
# 3  [加飯, 咖哩, 免錢, 加飯, 加醬, 真的, 照片, 雞肉, 咖哩, 青菜, 雞肉, 雞...
# 4  [口味, 過肉塊, 豬肉, 後腿, 牛肉, 牛腱, 大部分, 平價, 咖哩, 飯醬, 味道,...
#
#                                    word_list_bigrams
# 0                           [餐廳, 名稱, 咖哩, 消費, 時間, 例年]
# 1                                    [提供, 文章_不予, 保留]
# 2  [多訪, 綜合, 心得_標上, 時間, 地址, 台北市, 開封, 街段, 巷號, 電話, 營...
# 3  [加飯, 咖哩, 免錢, 加飯, 加醬, 真的, 照片, 雞肉, 咖哩, 青菜, 雞肉, 雞...
# 4  [口味, 過肉塊, 豬肉, 後腿, 牛肉, 牛腱, 大部分, 平價, 咖哩, 飯醬, 味道,...

# %%
word_freq = defaultdict(int)
# 計算詞頻
sents = metaData['word_list_bigrams'].tolist()
for sent in sents: # sent 中的每個句子
    for i in sent: # i 是句子中的每個字
        word_freq[i] += 1

# %%
print(f"total unique words in sentences: {len(word_freq)}")
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
# Out:
# total unique words in sentences: 47047
# ['餐廳', '不錯', '用餐', '好吃', '時間', '真的', '喜歡', '口感', '提供', '牛肉']

# %%
print(f"sentence number of corpus: {len(sents)}")
i = 0
for sent in sents:
    i = i + len(sent)
print(f"average length of sentences: {i/len(sents)}")
# Out:
# sentence number of corpus: 136363
# average length of sentences: 3.7056679597838125

# %% [markdown]
# Word2Vec 計算

# %%
# 環境變數設定
# %env PYTHONHASHSEED=2025
# Out:
# env: PYTHONHASHSEED=2025

# %%
# 查看機器的core
cores = multiprocessing.cpu_count()
print(f"number of cores: {cores}")
# Out:
# number of cores: 2

# %%
# 建立模型
w2v_model = Word2Vec(sents,
                     min_count=30,# 小於30次tf的字會被刪除
                     window=2,# 往左右各2的距離
                     vector_size=128,# vector 的維度
                     sample=0.005,# 愈小的話，高tf的字會不容易被選到
                     alpha=0.001,# learning rate
                     min_alpha=0.0005, # 迭代到最小的learning rate，learning rate會慢慢下降至min_alpha
                     negative=0,
                     workers=cores-1, # 用的cpu資源
                     seed=8787,
                     sg = 1,# 0/1 是否使用skip gram
                     epochs= 30,
                     hs=1 , # hierarchical softmax
                     )

# %% [markdown]
# 查看結果

# %%
# 檢查最相關的字
w2v_model.wv.most_similar('餐廳',topn=10)
# Out:
# [('餐館', 0.7247121930122375),
#  ('饗食天堂', 0.7000229358673096),
#  ('飯店', 0.6913735866546631),
#  ('酒館', 0.6886321306228638),
#  ('自助餐', 0.680745542049408),
#  ('酒店', 0.6723049879074097),
#  ('牛排館', 0.648144006729126),
#  ('市場', 0.6429240703582764),
#  ('鍋物', 0.6359825730323792),
#  ('火鍋店', 0.6341769099235535)]

# %%
w2v_model.wv.most_similar('火鍋',topn=10)
# Out:
# [('火鍋店', 0.7257478833198547),
#  ('鍋物', 0.7194325923919678),
#  ('麻辣鍋', 0.6645680069923401),
#  ('小火鍋', 0.6607419848442078),
#  ('平價', 0.6268301606178284),
#  ('燒烤', 0.6222773194313049),
#  ('火烤兩吃', 0.5980214476585388),
#  ('主打', 0.5930233597755432),
#  ('炭火', 0.5812309980392456),
#  ('燒肉', 0.574455201625824)]

# %%
w2v_model.wv.most_similar(['餐廳','火鍋'],topn=10)
# Out:
# [('火鍋店', 0.8214963674545288),
#  ('鍋物', 0.8187723755836487),
#  ('小火鍋', 0.7230461835861206),
#  ('牛排館', 0.6981977820396423),
#  ('餐館', 0.6958672404289246),
#  ('酒館', 0.6834900379180908),
#  ('湯鍋', 0.6741930246353149),
#  ('平價', 0.6723619699478149),
#  ('饗食天堂', 0.6664300560951233),
#  ('麻辣鍋', 0.6650515198707581)]

# %%
# 跟兩個字最不相關
w2v_model.wv.most_similar(negative=['火鍋','餐廳'],topn=10)
# Out:
# [('甜度', 0.4790411591529846),
#  ('很夠', 0.44384765625),
#  ('微焦', 0.4215758442878723),
#  ('一顆', 0.41370272636413574),
#  ('很濃', 0.40420448780059814),
#  ('玉米', 0.3886958062648773),
#  ('甜甜的', 0.38806071877479553),
#  ('微甜', 0.3724137544631958),
#  ('甜味', 0.3696207106113434),
#  ('增加', 0.3687766492366791)]

# %%
# 計算兩個字之間的關係
w2v_model.wv.similarity("台北","台南")
# Out:
# 0.8037215

# %%
w2v_model.wv.similarity("口感","香氣")
# Out:
# 0.7012158

# %%
# 比較字詞間，誰最不相關（邊緣）
w2v_model.wv.doesnt_match(["口感", "香氣", '台北'])
# Out:
# '台北'

# %%
# 相對關係
w2v_model.wv.most_similar(positive=["台北"], negative=["台南"], topn=5)
# Out:
# [('鄰近', 0.567126989364624),
#  ('站號_出口', 0.5396342873573303),
#  ('號近', 0.5062023997306824),
#  ('出口', 0.5033890008926392),
#  ('大安', 0.4773860275745392)]

# %%
# 取得所有的字
words = w2v_model.wv.key_to_index.keys()

# %% [markdown]
# 視覺化字之間的關係及將字做分群

# %%
# 降維：利用PCA tSNE

def reduceDim(mat,method:str='PCA',dim:str=2,perplexity = 25,learning_rate = 400):

    method_dict = {
        "PCA":PCA(n_components=dim,iterated_power = 1000,random_state=0),
        "TSNE":TSNE(n_components=dim,random_state=0,perplexity=perplexity,learning_rate=learning_rate),
    }
    new_feat = method_dict[method].fit_transform(mat)

    return new_feat

# %%
# 拿到list of words 的vector
def getVecs(model,words:list):
    vecs = []
    for i in words:
        vecs.append(model.wv[i])
    return np.vstack(vecs)

# %%
getVecs(w2v_model,['餐廳','美食'])
# Out:
# array([[-1.40910864e-01,  2.74175197e-01,  3.64399493e-01,
#          1.90469865e-02,  1.33085191e-01,  9.94050279e-02,
#          2.96392232e-01,  2.75583506e-01,  2.41275474e-01,
#          1.22653365e-01, -2.81718612e-01, -1.24076456e-02,
#         -4.42185372e-01, -1.48348942e-01, -3.80059153e-01,
#          3.26981664e-01,  3.32448840e-01, -5.90750426e-02,
#          2.16717258e-01,  3.51542443e-01,  1.17091730e-01,
#          3.83417577e-01,  1.81139052e-01,  1.89801514e-01,
#         -1.98258013e-01,  3.64341259e-01,  1.84618101e-01,
#          1.69582829e-01, -8.39067157e-03,  2.37369612e-01,
#          3.57207566e-01,  2.02896163e-01, -3.54313031e-02,
#          5.39162681e-02,  5.24267316e-01,  2.20389124e-02,
#         -1.45886853e-01, -4.03756618e-01, -8.00255835e-02,
#         -3.41891885e-01, -3.26304161e-03, -3.14895272e-01,
#         -2.76250809e-01, -2.79813677e-01, -3.13878134e-02,
#          7.30624422e-02, -6.28621206e-02,  4.35269654e-01,
#          1.21405900e-01, -1.74390048e-01,  1.77766502e-01,
#          1.84220403e-01, -4.09727186e-01, -3.07305664e-01,
#         -1.84388444e-01, -3.93555582e-01, -3.62192720e-01,
#         -4.43661362e-02, -3.82900447e-01,  4.48644280e-01,
#         -3.71173650e-01, -1.08693227e-01, -1.12628974e-01,
#         -8.22519213e-02,  1.14481278e-01, -2.03389406e-01,
#          1.17378637e-01,  7.66445398e-02,  5.90423420e-02,
#          2.41448253e-01,  4.56521064e-02,  1.88633293e-01,
#         -2.54376084e-01, -7.81885311e-02, -4.48349714e-02,
#          7.73708448e-02,  6.48896694e-02, -2.82549358e-04,
#         -7.28582442e-02,  4.02454957e-02, -8.02493766e-02,
#          1.14298068e-01, -1.44497663e-01,  1.86087191e-01,
#          2.10640386e-01, -7.07451720e-03,  8.98711309e-02,
#         -1.40107833e-02, -1.65622413e-01,  4.72521149e-02,
#          9.01965573e-02, -1.54129505e-01, -2.18345925e-01,
#         -4.56336252e-02,  8.97385105e-02, -3.61953340e-02,
#          6.16627298e-02, -1.45347506e-01,  1.58525914e-01,
#          2.61736125e-01, -1.61261961e-01,  9.86530036e-02,
#         -2.14859899e-02,  2.73189455e-01, -1.11986592e-01,
#          3.78342211e-01, -1.07532807e-01,  2.28203058e-01,
#          8.29172805e-02,  7.90646076e-02]], dtype=float32)

# %%
# 擴展相似的字詞
def expandPosWord(model, words:list, top_n:int, split = True):

    if split == False:
        wp = model.wv.most_similar(words,topn = top_n)
        return wp
    expand = []

    for w in words:
        wp = model.wv.most_similar(w,topn = top_n)
        for i in wp:
            expand.append(i[0])

    return list(set(expand))

# %%
expandPosWord(w2v_model,['餐廳','熱炒'],top_n = 10)
# Out:
# ['元素',
#  '主題',
#  '火鍋店',
#  '蔬食',
#  '台式',
#  '自助餐',
#  '酒店',
#  '中式',
#  '素食',
#  '創意',
#  '傳統',
#  '市場',
#  '牛排館',
#  '鍋物',
#  '特色',
#  '燒烤',
#  '饗食天堂',
#  '飯店',
#  '酒館',
#  '餐館']

# %%
# 畫出兩維的散佈圖
def plotScatter(vec_df):
    """
    vec_df: 字詞及其兩個維度的值
    """
    plt.figure(figsize=(15,15))
    fontManager.addfont('./TaipeiSansTCBeta-Regular.ttf')
    plt.rcParams['font.sans-serif'] = ['Taipei Sans TC Beta']
    plt.rcParams['font.size'] = '16'

    p = sns.scatterplot(x="dim1", y="dim2",
                  data=vec_df)
    for line in range(0, vec_df.shape[0]):
         p.text(vec_df["dim1"][line],
                 vec_df['dim2'][line],
                 '  ' + vec_df["word"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 weight='normal'
                ).set_size(15)
    plt.show()

# 畫出三維的散佈圖
def plotScatter3D(vec_df):
    vec_df['size'] = .5
    if 'color' not in vec_df.columns:
        vec_df['color'] = 'blue'
    fig = px.scatter_3d(
        vec_df,'dim1','dim2','dim3',text = 'word',width=800, height=800,color = 'color',size = 'size'

    )

    fig.show()

# %%
sample_words = np.random.choice(list(words),300,replace=False).tolist()

feat = getVecs(model=w2v_model,words=sample_words)
print(feat.shape)
new_feat = reduceDim(feat,method='TSNE',perplexity=20,learning_rate = 800)
print(new_feat.shape)
# Out:
# (300, 128)
# (300, 2)

# %%
word_df = pd.DataFrame({
    "word":sample_words,
    "dim1":new_feat[:,0],
    "dim2":new_feat[:,1],
})

# %%
plotScatter(word_df)

# %% [markdown]
# 3D 散狀圖

# %%
new_feat = reduceDim(feat,dim = 3,method = 'PCA' )
print(new_feat.shape)
word_df = pd.DataFrame({
    "word":sample_words,
    "dim1":new_feat[:,0],
    "dim2":new_feat[:,1],
    "dim3":new_feat[:,2],
})
plotScatter3D(word_df)
# Out:
# (300, 3)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2f214fdc-b1bd-46e4-bf44-de9f2a9fbf96" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f214fdc-b1bd-46e4-bf44-de9f2a9fbf96")) {                    Plotly.newPlot(                        "2f214fdc-b1bd-46e4-bf44-de9f2a9fbf96",                        [{"hovertemplate":"color=blue\u003cbr\u003edim1=%{x}\u003cbr\u003edim2=%{y}\u003cbr\u003edim3=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"blue","marker":{"color":"#636efa","size":[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5],"sizemode":"area","sizeref":0.00125,"symbol":"circle"},"mode":"markers+text","name":"blue","scene":"scene","showlegend":true,"text":["蛤蠣","有人","小朋友","感到","桂花","週日","醬汁","過了","餃類","上次","街號","小美","營業時間","達成","午餐","各類","金額","建議","偏重","狀況","表現","時尚","脆皮","回去","吃不飽","麻辣","喝到","吃得飽","酥皮","粵菜","醬油","酸味","供選擇","明治","培根","鮮奶油","則有","芭樂","瞬間","細節","說真的","崇德","擺放","層次","清香","顯得","小時","一段時間","炒年糕","果凍","辰園","之下","融入","塑膠","販售","探索_廚房","雞腿","肉量","饗食天堂","調配","米粉","香辣","生啤酒","超過","沒點","電話","加熱","兩道","這一鍋","肥美","奇異果","西米露","很甜","仔細","番茄","胡椒","有趣","冰箱","兌換","拿到","結論","調整","獨立","蝦餃","近期","版本","區有","異國","豬肋排","取消","冰塊","腥味","防疫","爆米花","完畢","放棄","山藥","機會","脆度","住宿","酒館","花費","厚切","加價","沙瓦","也許","牛小排","胃口","看似","運氣","牛板腱","普普","自助式","交通","懷念","手工","採用","滿滿","多樣化","有限","選用","阿姨","旅伴","四段","喝完","馬虎","美麗","加分","放入","很足","乳酪","媽媽","過的","我蠻","麻辣火鍋","看著","補菜","大大的","台北市","五花","總覺","芝麻","紅酒","濃濃的","續點","不錯","沒多久","溫度","自助餐","卡士","終於","雞鍋","下午","配料","推出","義式","三重","滿分","佛心","餡料","工作","開胃菜","整潔","比薩","去過","桌距","煮起來","部位","香料","店家","中卷","鮮奶","烏龍茶","越來越","接待","臺北市","了點","布蕾","炒飯","桌椅","稱讚","吃得出","這天","沒什麼","送餐","涼拌","再來","酒吧","滿多","草莓","不停","超棒","現做","內臟","南港","感受","商業","蒜味","椅子","蔓越莓","誇張","金沙","顧客","芝麻醬","開幕","期待","入場","中央","河粉","後方","西門","香醇","回到","款式","減少","大阪","提早","感想","中壢","清爽","特別","烏梅汁","號樓","餐包","取餐","關係","部落","軟嫩","稍嫌","步行","吸飽","牛筋","中午","位子","薄片","大白菜","只點","擁有","分量","麻辣鍋","專人","東京","花生粉","非常適合","午間","香菇","太重","方式","泰式","欣賞","綿密","現點","常見","電梯","現煎","整體","壽司","檸檬汁","類型","至少","橫膈膜","事先","光顧","主菜","西瓜","高湯","評分","台北","中式","提到","澎湖","大鍋","嘗試","休息","更換","世界","身為","排餐","一碗","失望","時會","食堂","八種","呈現","披薩","隨便","杏鮑菇","蝦餅","有機","莫凡","好讀","人數","切開","負擔","給你","蔬食","質感","紅茶","一貫","員工"],"x":[0.442121,-0.19202986,0.0033832297,0.011182535,0.34824598,-2.7676637,0.80754477,-0.3791742,0.42725065,-0.30135772,-2.4353805,0.6427377,-2.7530704,-0.5963916,-1.3309712,0.34540695,-0.45041636,-0.20529144,0.38392848,-0.18679963,0.586491,-0.45418435,0.57552874,-0.0947027,-0.03178003,0.4694361 ...

# %% [markdown]
# 將字分群

# %%
# !pip install scikit-learn-extra
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from scikit-learn-extra) (1.26.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn-extra) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn-extra) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.6.0)
# Downloading scikit_learn_extra-0.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 34.7 MB/s eta 0:00:00
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0

# %%
# 分群
from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
# 只使用word vector 去分群
def cluster(X,method = 'kmeans',n = 2):

    method_dict = {
        'kmeans':KMeans(n_clusters=n, random_state=0),
        'kmedos':KMedoids(n_clusters=n, random_state=0)
    }
    method_dict[method].fit(X)
    result = method_dict[method].predict(X)
    return result

# %%
new_feat = reduceDim(feat,method='PCA',dim = 20)
d3_feat = reduceDim(feat,method='PCA',dim = 3)
word_df = pd.DataFrame({
    "word":sample_words,
    "color":cluster(new_feat,n=4),
    "dim1":d3_feat[:,0],
    "dim2":d3_feat[:,1],
    "dim3":d3_feat[:,2],

})
plotScatter3D(word_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e93d9d25-0d71-409f-8642-200b5b76b58c" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e93d9d25-0d71-409f-8642-200b5b76b58c")) {                    Plotly.newPlot(                        "e93d9d25-0d71-409f-8642-200b5b76b58c",                        [{"hovertemplate":"dim1=%{x}\u003cbr\u003edim2=%{y}\u003cbr\u003edim3=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003eword=%{text}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2,0,0,0,2,1,2,0,2,0,1,3,1,0,0,2,0,0,2,0,2,0,2,0,0,2,3,0,2,0,2,2,2,3,2,2,2,3,2,0,0,0,0,2,2,0,0,0,2,3,0,0,2,0,0,0,2,2,0,2,2,2,2,0,0,1,0,2,0,2,3,2,2,0,2,2,2,2,0,2,0,0,0,2,0,0,3,2,2,0,2,2,0,3,0,0,2,0,2,0,0,0,2,2,3,0,2,2,2,0,2,2,0,0,2,3,0,2,2,0,2,0,2,1,2,2,0,0,2,2,3,2,2,2,0,0,0,0,1,2,2,3,2,2,2,2,0,2,0,3,0,2,0,2,0,3,0,2,0,2,0,2,0,2,0,0,2,2,2,0,2,2,3,0,0,1,2,2,2,0,0,2,0,2,0,2,0,0,2,3,0,2,2,2,0,2,0,2,0,3,0,2,0,2,0,0,0,0,2,0,0,2,0,2,0,0,0,0,0,2,2,3,1,2,0,0,0,2,2,0,2,2,0,0,2,2,2,0,2,0,0,0,2,2,0,2,2,0,2,0,2,2,2,0,2,2,2,2,0,0,2,0,0,2,3,2,0,0,2,0,2,2,2,0,2,0,0,2,2,2,0,0,3,2,2,2,2,2,2,3,0,0,2,2,2,0,0,3,0,0],"coloraxis":"coloraxis","size":[0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5],"sizemode":"area","sizeref":0.00125,"symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["蛤蠣","有人","小朋友","感到","桂花","週日","醬汁","過了","餃類","上次","街號","小美","營業時間","達成","午餐","各類","金額","建議","偏重","狀況","表現","時尚","脆皮","回去","吃不飽","麻辣","喝到","吃得飽","酥皮","粵菜","醬油","酸味","供選擇","明治","培根","鮮奶油","則有","芭樂","瞬間","細節","說真的","崇德","擺放","層次","清香","顯得","小時","一段時間","炒年糕","果凍","辰園","之下","融入","塑膠","販售","探索_廚房","雞腿","肉量","饗食天堂","調配","米粉","香辣","生啤酒","超過","沒點","電話","加熱","兩道","這一鍋","肥美","奇異果","西米露","很甜","仔細","番茄","胡椒","有趣","冰箱","兌換","拿到","結論","調整","獨立","蝦餃","近期","版本","區有","異國","豬肋排","取消","冰塊","腥味","防疫","爆米花","完畢","放棄","山藥","機會","脆度","住宿","酒館","花費","厚切","加價","沙瓦","也許","牛小排","胃口","看似","運氣","牛板腱","普普","自助式","交通","懷念","手工","採用","滿滿","多樣化","有限","選用","阿姨","旅伴","四段","喝完","馬虎","美麗","加分","放入","很足","乳酪","媽媽","過的","我蠻","麻辣火鍋","看著","補菜","大大的","台北市","五花","總覺","芝麻","紅酒","濃濃的","續點","不錯","沒多久","溫度","自助餐","卡士","終於","雞鍋","下午","配料","推出","義式","三重","滿分","佛心","餡料","工作","開胃菜","整潔","比薩","去過","桌距","煮起來","部位","香料","店家","中卷","鮮奶","烏龍茶","越來越","接待","臺北市","了點","布蕾","炒飯","桌椅","稱讚","吃得出","這天","沒什麼","送餐","涼拌","再來","酒吧","滿多","草莓","不停","超棒","現做","內臟","南港","感受","商業","蒜味","椅子","蔓越莓","誇張","金沙","顧客","芝麻醬","開幕","期待","入場","中央","河粉","後方","西門","香醇","回到","款式","減少","大阪","提早","感想","中壢","清爽","特別","烏梅汁","號樓","餐包","取餐","關係","部落","軟嫩","稍嫌","步行","吸飽","牛筋","中午","位子","薄片","大白菜","只 ...

# %% [markdown]
# ####（2）如何使用別人訓練好的word2vec模型

# %% [markdown]
# 使用臺北醫學大學做的預訓練 Word2Vec 模型當範例，需將模型檔下載下來
# （來源：http://nlp.tmu.edu.tw/word2vec/index.html ）

# %%
model_tmu = KeyedVectors.load_word2vec_format('./tmunlp_1.6B_WB_50dim_2020v1.bin', unicode_errors='ignore', binary=True)

# %%
model_tmu.most_similar('癌症',topn=10)
# Out:
# [('肝癌', 0.8965061902999878),
#  ('乳癌', 0.894655168056488),
#  ('肺癌', 0.8924040198326111),
#  ('肝病', 0.8478196859359741),
#  ('大腸癌', 0.8448510766029358),
#  ('糖尿病', 0.8433824181556702),
#  ('口腔癌', 0.8214656710624695),
#  ('疾病', 0.8192287683486938),
#  ('胃癌', 0.8169611096382141),
#  ('腸癌', 0.8160045742988586)]

# %%
model_tmu.most_similar('咳嗽',topn=10)
# Out:
# [('流鼻水', 0.8725693225860596),
#  ('鼻塞', 0.8663491010665894),
#  ('嘔吐', 0.8655411601066589),
#  ('腹瀉', 0.8551325798034668),
#  ('感冒', 0.8539074063301086),
#  ('乾咳', 0.8232213854789734),
#  ('胸悶', 0.8225348591804504),
#  ('胸痛', 0.8140345811843872),
#  ('腹痛', 0.8083592057228088),
#  ('頭暈', 0.8059035539627075)]

# %%
model_tmu.most_similar(positive=['疾病','咳嗽'],topn=10)
# Out:
# [('症狀', 0.8799884915351868),
#  ('癥狀', 0.8648518919944763),
#  ('哮喘', 0.8594630360603333),
#  ('慢性', 0.8578190803527832),
#  ('氣喘', 0.8548911809921265),
#  ('感冒', 0.8509713411331177),
#  ('腹瀉', 0.8316847085952759),
#  ('病症', 0.8148555159568787),
#  ('急性', 0.8118695020675659),
#  ('癲癇', 0.802987277507782)]

# %% [markdown]
# ### Transformers Embeddings

# %% [markdown]
# #### 使用 Sentence-Transformer 套件
# 參考資料：https://www.sbert.net/index.html

# %%
# !pip install -U sentence-transformers

# %%
from sentence_transformers import SentenceTransformer, models, util

# %% [markdown]
# #### 小模型，以BERT為範例

# %% [markdown]
# 註：在挑選語言模型時需確認其訓練資料的來源，因為不一定都具備跨語言的能力。
# 接下來將以針對英文、中文以及多語言進行訓練的三種BERT模型做範例。

# %%
# 英文 bert-base-uncased
bert_en = SentenceTransformer('google-bert/bert-base-uncased')

bert_en.tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
#
#
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name google-bert/bert-base-uncased. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# 0

# %%
bert_en.get_max_seq_length()
# Out:
# 512

# %%
example_text = "This framework generates embeddings for each input sentence"
example_embeddings = bert_en.encode(example_text)

print(example_embeddings.shape)
print("=======================")
print(example_embeddings)
# Out:
# (768,)
# =======================
# [-1.25634447e-01 -2.35393215e-02  9.72139984e-02 -2.14601994e-01
#  -4.24759835e-02 -7.68930186e-03  1.66508660e-01  2.09751680e-01
#   1.94057614e-01 -9.31541249e-02 -1.04051024e-01 -1.99633449e-01
#  -3.48384082e-01  8.10462981e-02 -1.62067376e-02  1.90525785e-01
#   5.29323646e-04  1.45439476e-01 -5.53638907e-04 -1.58491164e-01
#   1.94275320e-01  1.59165785e-01 -5.99901438e-01  2.65522301e-01
#   7.47946084e-01 -2.46574776e-03  1.04436524e-01  1.66958421e-01
#  -3.53779286e-01  1.39418453e-01  3.89937535e-02  6.57109916e-01
#  -6.23263745e-03 -2.85023808e-01 -1.56141207e-01  8.45851898e-02
#   1.65655270e-01 -2.55370349e-01 -1.16442792e-01  9.59287211e-02
#  -6.72327161e-01 -3.47994924e-01  8.42589512e-02 -2.06027687e-01
#  -5.32229878e-02 -4.90706921e-01 -9.41142626e-03 -3.81041527e-01
#   5.67959808e-02 -6.35588527e-01 -1.04700673e+00  3.73333335e-01
#   1.31077304e-01  3.08176994e-01 -2.27984294e-01  8.04124177e-01
#   1.21666521e-01 -7.21640170e-01  3.69302332e-01 -1.17350049e-01
#   1.25592634e-01 -9.21371281e-02 -3.33507694e-02 -3.41472805e-01
#   3.29598635e-01  5.15490830e-01 -1.07765250e-01  5.64304471e-01
#  -1.15020931e+00  5.37593774e-02 -5.84979117e-01 -1.56924158e-01
#  -7.54174143e-02  8.65553543e-02 -3.39148790e-01  1.77597016e-01
#  -4.58922654e-01  3.00487250e-01 -2.28236601e-01 -4.51446384e-01
#  -4.22899097e-01  5.34952581e-01  1.18460529e-01  2.06683785e-01
#   5.75566232e-01  1.05686858e-01 -1.89213976e-02  2.41077170e-01
#  -7.60485709e-01  4.51188356e-01  1.08974352e-01 -2.92842120e-01
#  -2.29266942e-01  1.28677234e-01  5.19238472e-01  4.46198523e-01
#  -2.17200249e-01  1.24731049e-01  2.33080000e-01  3.94091547e-01
#   5.34902140e-02 -3.54801327e-01  2.86019623e-01  1.59943715e-01
#  -4.75198597e-01 -1.87098727e-01 -4.10266340e-01  2.32392088e-01
#   3.23132068e-01  2.12779194e-01  1.64344683e-01 -1.16784461e-01
#   2.05314785e-01 -5.09796798e-01 -1.68706477e-01 -1.55170441e-01
#   1.79133758e-01  4.82844055e-01  1.00590400e-01 -1.98781401e-01
#  -3.82300735e-01  3.55330497e-01  6.48622438e-02 -1.92091495e-01
#  -3.91457051e-01  1.28471985e-01  9.81824696e-02  3.15605760e-01
#  -2.18291562e-02  2.85419524e-01 -8.91216546e-02 -3.17807019e-01
#  -5.47043920e-01 -3.72902215e-01  1.59742579e-01 -1.72195409e-03
#  -3.52221429e-01 -3.79847646e-01 -3.23166788e-01  2.29027659e-01
#   6.05799437e-01 -1.80942148e-01 -3.67385834e-01  2.71242440e-01]

# %%
# 示範句子
sentences = [
    "This framework generates embeddings for each input sentence",
    "The quick brown fox jumps over the lazy dog.",
    "The speedy black dog leaps across the cat."
]

# 使用 encode() 對資料做embedding
embeddings_en = bert_en.encode(sentences)

# Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings_en, embeddings_en)

# 印出句子間的cosine similarity分數
result = []
for i in range(len(sentences)):
    for j in range(i+1, len(sentences)):
        result.append([sentences[i], sentences[j], cosine_scores[i][j].item()])

result_df = pd.DataFrame(result, columns=["sentence1", "sentence2", "score"])
result_df.sort_values("score", ascending = False)
# Out:
#                                            sentence1  \
# 2       The quick brown fox jumps over the lazy dog.
# 0  This framework generates embeddings for each i...
# 1  This framework generates embeddings for each i...
#
#                                       sentence2     score
# 2    The speedy black dog leaps across the cat.  0.880907
# 0  The quick brown fox jumps over the lazy dog.  0.499376
# 1    The speedy black dog leaps across the cat.  0.480858

# %% [markdown]
# 因為後續在查看結果時會一直使用到此程式碼，所以包成function以便之後使用。

# %%
# 回傳cosine similarity分數
def get_result_df(sentences, cosine_scores):

  result = []
  for i in range(len(sentences)):
      for j in range(i+1, len(sentences)):
          result.append([sentences[i], sentences[j], cosine_scores[i][j].item()])

  result_df = pd.DataFrame(result, columns=["sentence1", "sentence2", "score"])
  result_df = result_df.sort_values("score", ascending = False)

  return result_df

# %% [markdown]
# 中文 bert-base-chinese

# %%
# 中文 bert-base-chinese
bert_ch = SentenceTransformer('google-bert/bert-base-chinese')

bert_ch.tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name google-bert/bert-base-chinese. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/412M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/269k [00:00<?, ?B/s]
# 0

# %%
# 示範句子
sentences = [
    "今天天氣很好。",
    "今天是個晴空萬里的好天氣。",
    "我晚上想去公園散步。"
]

# 使用 encode() 對資料做embedding
embeddings_ch = bert_ch.encode(sentences)

# Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings_ch, embeddings_ch)

# 印出句子間的cosine similarity分數
result_df = get_result_df(sentences, cosine_scores)
result_df
# Out:
#        sentence1      sentence2     score
# 0        今天天氣很好。  今天是個晴空萬里的好天氣。  0.914067
# 1        今天天氣很好。     我晚上想去公園散步。  0.787589
# 2  今天是個晴空萬里的好天氣。     我晚上想去公園散步。  0.759642

# %% [markdown]
# 多語言 bert-base-multilingual-cased

# %%
# 多語言 bert-base-multilingual-cased
bert_multi = SentenceTransformer('google-bert/bert-base-multilingual-cased')

bert_multi.tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name google-bert/bert-base-multilingual-cased. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# 0

# %%
# 示範句子
sentences = [
    "This framework generates embeddings for each input sentence.",
    "The quick brown fox jumps over the lazy dog.",
    "敏捷的棕色狐狸跳過了懶惰的狗。"
]

# 使用 encode() 對資料做embedding
embeddings_multi = bert_multi.encode(sentences)

# Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings_multi, embeddings_multi)

# 印出句子間的cosine similarity分數
result_df = get_result_df(sentences, cosine_scores)
result_df
# Out:
#                                            sentence1  \
# 2       The quick brown fox jumps over the lazy dog.
# 1  This framework generates embeddings for each i...
# 0  This framework generates embeddings for each i...
#
#                                       sentence2     score
# 2                               敏捷的棕色狐狸跳過了懶惰的狗。  0.588525
# 1                               敏捷的棕色狐狸跳過了懶惰的狗。  0.362765
# 0  The quick brown fox jumps over the lazy dog.  0.350700

# %% [markdown]
# #### 大模型範例

# %%
# !pip install tiktoken
# !pip install utils

# %% [markdown]
# #### (1)API based

# %% [markdown]
# ##### OpenAI

# %% [markdown]
# **注意**
# Openai的API會要求綁定信用卡後才能使用，且綁定信用卡後會刷5美金的初始費用。
# 請自行斟酌是否要嘗試這一部分的程式碼！

# %%
# !pip install --upgrade openai

# %%
# from openai import OpenAI
import openai
import os

openai.api_key = '你的API_KEY' # 設置API_KEY

def get_embedding_openai(text, model):
   #text = text.replace("\n", " ")
   return openai.embeddings.create(input = [text], model=model).data[0].embedding

# %%
embedding_model = "text-embedding-3-small"
embedding_encoding = "cl100k_base"
max_tokens = 8000  # the maximum for text-embedding-3-small is 8191

# %%
# 示範句子
sentences = [
    "This framework generates embeddings for each input sentence.",
    "The quick brown fox jumps over the lazy dog.",
    "敏捷的棕色狐狸跳過了懶惰的狗。",
    "速い茶色のキツネが怠惰な犬を飛び越える"
]

# 取得每一句的embedding
embeddings_openai = [get_embedding_openai(text, model=embedding_model) for text in sentences]

# Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings_openai, embeddings_openai)

# 印出句子間的cosine similarity分數
result_df = get_result_df(sentences, cosine_scores)
result_df
# Out:
#                                            sentence1  \
# 3       The quick brown fox jumps over the lazy dog.
# 5                                    敏捷的棕色狐狸跳過了懶惰的狗。
# 4       The quick brown fox jumps over the lazy dog.
# 2  This framework generates embeddings for each i...
# 0  This framework generates embeddings for each i...
# 1  This framework generates embeddings for each i...
#
#                                       sentence2     score
# 3                               敏捷的棕色狐狸跳過了懶惰的狗。  0.598646
# 5                           速い茶色のキツネが怠惰な犬を飛び越える  0.572962
# 4                           速い茶色のキツネが怠惰な犬を飛び越える  0.493020
# 2                           速い茶色のキツネが怠惰な犬を飛び越える  0.050631
# 0  The quick brown fox jumps over the lazy dog.  0.030699
# 1                               敏捷的棕色狐狸跳過了懶惰的狗。  0.024859

# %% [markdown]
# ##### Cohere

# %%
# !pip install cohere
# Out:
# Collecting cohere
#   Downloading cohere-5.15.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.11/dist-packages (from cohere) (0.28.1)
# Collecting httpx-sse==0.4.0 (from cohere)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from cohere) (2.11.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.11/dist-packages (from cohere) (2.33.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.11/dist-packages (from cohere) (0.21.1)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere)
#   Downloading types_requests-2.32.0.20250328-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from cohere) (4.13.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.21.2->cohere) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.21.2->cohere) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.21.2->cohere) (1.0.8)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->cohere) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers<1,>=0.15->cohere) (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.67.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.3.1)
# Downloading cohere-5.15.0-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 8.2 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading fastavro-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 73.1 MB/s eta 0:00:00
# Downloading types_requests-2.32.0.20250328-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests, httpx-sse, fastavro, cohere
# Successfully installed cohere-5.15.0 fastavro-1.10.0 httpx-sse-0.4.0 types-requests-2.32.0.20250328

# %%
import cohere

co = cohere.Client("你的API_KEY") # 設置API_KEY

embedding_model = "embed-multilingual-v3.0"

def get_embedding_cohere(text, model):
   #text = text.replace("\n", " ")
   return co.embed(texts=[text], model=model, input_type="classification").embeddings[0]

# %%
# 示範句子
sentences = [
    "This framework generates embeddings for each input sentence.",
    "The quick brown fox jumps over the lazy dog.",
    "敏捷的棕色狐狸跳過了懶惰的狗。",
    "速い茶色のキツネが怠惰な犬を飛び越える"
]

# 使用 encode() 對資料做embedding
embeddings_cohere = [get_embedding_cohere(text, model=embedding_model) for text in sentences]

# Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings_cohere, embeddings_cohere)

# 印出句子間的cosine similarity分數
result_df = get_result_df(sentences, cosine_scores)
result_df
# Out:
#                                            sentence1  \
# 5                                    敏捷的棕色狐狸跳過了懶惰的狗。
# 3       The quick brown fox jumps over the lazy dog.
# 4       The quick brown fox jumps over the lazy dog.
# 1  This framework generates embeddings for each i...
# 2  This framework generates embeddings for each i...
# 0  This framework generates embeddings for each i...
#
#                                       sentence2     score
# 5                           速い茶色のキツネが怠惰な犬を飛び越える  0.707117
# 3                               敏捷的棕色狐狸跳過了懶惰的狗。  0.706838
# 4                           速い茶色のキツネが怠惰な犬を飛び越える  0.631464
# 1                               敏捷的棕色狐狸跳過了懶惰的狗。  0.279418
# 2                           速い茶色のキツネが怠惰な犬を飛び越える  0.261698
# 0  The quick brown fox jumps over the lazy dog.  0.227097

# %% [markdown]
# #### (2) Open Source LLM

# %%
from huggingface_hub import notebook_login
notebook_login() # 輸入Hugging Face 帳號的Token
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ##### Microsoft - Phi 4

# %%
# model_phi3 = SentenceTransformer('microsoft/Phi-3.5-mini-instruct')
model_phi4 = SentenceTransformer('microsoft/Phi-4-mini-instruct')

model_phi4.tokenizer.pad_token = model_phi4.tokenizer.eos_token
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name microsoft/Phi-4-mini-instruct. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.77G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/2.93k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.91M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/587 [00:00<?, ?B/s]

# %%
# 示範句子
sentences = [
    "This framework generates embeddings for each input sentence",
    "The quick brown fox jumps over the lazy dog.",
    "The speedy black dog leaps across the cat."
]

# 使用 encode() 對資料做embedding
embeddings_phi4 = model_phi4.encode(sentences)

# Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings_phi4, embeddings_phi4)

# 印出句子間的cosine similarity分數
result_df = get_result_df(sentences, cosine_scores)
result_df
# Out:
#                                            sentence1  \
# 2       The quick brown fox jumps over the lazy dog.
# 1  This framework generates embeddings for each i...
# 0  This framework generates embeddings for each i...
#
#                                       sentence2     score
# 2    The speedy black dog leaps across the cat.  0.919915
# 1    The speedy black dog leaps across the cat.  0.845914
# 0  The quick brown fox jumps over the lazy dog.  0.826574

# %% [markdown]
# 這裡需注意一下，上述的開源LLM基本上是decoder-only，它們主要的任務目標是要生成下一個字，並不是主要拿來做sentence embedding的。
# 有興趣的同學可以參考[embedding相關任務的leaderboard](https://huggingface.co/spaces/mteb/leaderboard)，試試上面的模型。

# %% [markdown]
# ### 使用embedding做NLP任務

# %% [markdown]
# #### 相似文件

# %%
df_similar = origin_data[['system_id','artTitle', 'artContent']]
df_similar['artContent'] = df_similar['artContent'].apply(lambda x: re.sub('[^\u4e00-\u9fff]+', '',x))

df_similar.head(5)
# Out:
# <ipython-input-16-ba0ea2bb5f29>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_similar['artContent'] = df_similar['artContent'].apply(lambda x: re.sub('[^\u4e00-\u9fff]+', '',x))
#    system_id                   artTitle  \
# 0          1         [食記]台北中正濃咖哩平價美味份量大
# 1          2        [抱怨]ATT4FUN乾杯點沙朗多注意
# 2          3        [食記]台北大安區六張犁站捷運小慧涼麵
# 3          4      [食記]福岡-運河城旁國產牛燒肉-WEST
# 4          5  [食記]長榮皇璽桂冠艙飛機餐SEA-TPE聖誕好運
#
#                                           artContent
# 0  餐廳名稱濃咖哩消費時間年月例年月未提供則文章不予保留多訪綜合心得也請標上起迄時間地址台北市開...
# 1  餐廳名稱乾杯地址乾杯電話消費時間年月號事發經過元旦跟女朋友晚上訂了位以前都會點上等牛排吃過很...
# 2  餐廳名稱小慧涼麵消費時間年月起多訪地址台北市大安區臥龍街巷號電話營業時間週日公休每人平均價位...
# 3  消費時間年月在運河城逛累了當然要吃東西補充體力了喔最大的特色就是有包廂的設計不只提供中文菜單...
# 4  店名長榮皇璽桂冠艙飛機餐地址無電話無營業時間依機艙供餐時間為準個人平均消費依機票價格為主適合...

# %% [markdown]
# 使用 bert-base-chinese 做示範

# %%
# 中文 bert-base-chinese
bert_ch = SentenceTransformer('google-bert/bert-base-chinese', device='cuda')

bert_ch.tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name google-bert/bert-base-chinese. Creating a new one with mean pooling.
# config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/412M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/269k [00:00<?, ?B/s]
# 0

# %% [markdown]
# 取得整個文集的 embeddings

# %%
corpus_embeddings = bert_ch.encode(
    df_similar['artContent'],
    convert_to_tensor=True,
    batch_size=32
)

# %%
query_num = 6 # 指定文章

# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = 5


query_embedding = bert_ch.encode(df_similar['artContent'][query_num], convert_to_tensor=True)

# We use cosine-similarity and torch.topk to find the highest 5 scores
cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
top_results = torch.topk(cos_scores, k=top_k)

print("\n\n======================\n\n")
print("Query:", df_similar['artTitle'][query_num])
print("\n 資料集中前五相似的文章:")

for score, idx in zip(top_results[0], top_results[1]):
    print(df_similar['artTitle'][idx.item()], "(Score: {:.4f})".format(score))

print("\n\n======================\n\n")
# Out:
# ======================
#
#
# Query: [食記]台中新開幕平價火鍋-聊聊鍋物(東海店)
#
#  資料集中前五相似的文章:
# [食記]台中新開幕平價火鍋-聊聊鍋物(東海店) (Score: 1.0000)
# [食記]台北這一小鍋，台北車站人氣小火鍋 (Score: 0.9923)
# [食記]高雄一炎九鼎-本體是薯條吃到飽平價火鍋 (Score: 0.9903)
# [食記]新北辛海鍋物299免服務費平價吃到飽 (Score: 0.9898)
# [食記]台中FOND訪韓國傳統豆腐鍋(老虎城店) (Score: 0.9897)
#
#
# ======================

# %%
query_num = 30

top_k = 5

query_embedding = bert_ch.encode(df_similar['artContent'][query_num], convert_to_tensor=True)

# We use cosine-similarity and torch.topk to find the highest 5 scores
cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
top_results = torch.topk(cos_scores, k=top_k)

print("\n\n======================\n\n")
print("Query:", df_similar['artTitle'][query_num])
print("\n 資料集中前五相似的文章:")

for score, idx in zip(top_results[0], top_results[1]):
    print(df_similar['artTitle'][idx.item()], "(Score: {:.4f})".format(score))

print("\n\n======================\n\n")
# Out:
# ======================
#
#
# Query: [食記]台北哞哞屋和牛燒肉
#
#  資料集中前五相似的文章:
# [食記]台北哞哞屋和牛燒肉 (Score: 1.0000)
# [食記]台北金舌燒肉KintanBuffet (Score: 0.9885)
# [食記]西門町肉次方燒肉吃到飽 (Score: 0.9878)
# [食記]桃園-單點式炭火燒肉-米炭火燒肉小酒館 (Score: 0.9870)
# [食記]-羿燒肉-中壢少見的幫剝蝦殼服務 (Score: 0.9866)
#
#
# ======================
